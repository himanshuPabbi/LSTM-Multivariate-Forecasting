# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Dropout, BatchNormalization
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
df_train = pd.read_csv('LSTM-Multivariate_pollution.csv')
df_train
# Out:
#                       date  pollution  dew  temp   press wnd_dir  wnd_spd  \
# 0      2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79
# 1      2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68
# 2      2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57
# 3      2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36
# 4      2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25
# ...                    ...        ...  ...   ...     ...     ...      ...
# 43795  2014-12-31 19:00:00        8.0  -23  -2.0  1034.0      NW   231.97
# 43796  2014-12-31 20:00:00       10.0  -22  -3.0  1034.0      NW   237.78
# 43797  2014-12-31 21:00:00       10.0  -22  -3.0  1034.0      NW   242.70
# 43798  2014-12-31 22:00:00        8.0  -22  -4.0  1034.0      NW   246.72
# 43799  2014-12-31 23:00:00       12.0  -21  -3.0  1034.0      NW   249.85
#
#        snow  rain
# 0         0     0
# 1         0     0
# 2         0     0
# 3         1     0
# 4         2     0
# ...     ...   ...
# 43795     0     0
# 43796     0     0
# 43797     0     0
# 43798     0     0
# 43799     0     0
#
# [43800 rows x 9 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43800 entries, 0 to 43799
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       43800 non-null  object
#  1   pollution  43800 non-null  float64
#  2   dew        43800 non-null  int64
#  3   temp       43800 non-null  float64
#  4   press      43800 non-null  float64
#  5   wnd_dir    43800 non-null  object
#  6   wnd_spd    43800 non-null  float64
#  7   snow       43800 non-null  int64
#  8   rain       43800 non-null  int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 3.0+ MB

# %%
df_test = pd.read_csv("pollution_test_data1.csv")
df_test
# Out:
#      dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 0    -16     4   1027      SE     3.58     0     0        128
# 1    -17     5   1027      SE     7.60     0     0         77
# 2    -16     4   1027      SE     9.39     0     0         65
# 3    -16     1   1028      cv     0.89     0     0         79
# 4    -14     0   1028      NE     1.79     0     0         93
# ..   ...   ...    ...     ...      ...   ...   ...        ...
# 341  -23    -2   1034      NW   231.97     0     0          8
# 342  -22    -3   1034      NW   237.78     0     0         10
# 343  -22    -3   1034      NW   242.70     0     0         10
# 344  -22    -4   1034      NW   246.72     0     0          8
# 345  -21    -3   1034      NW   249.85     0     0         12
#
# [346 rows x 8 columns]

# %%
print(df_train.isnull().sum() , "\n---------------- \n" , df_test.isnull().sum() )
# Out:
# date         0
# pollution    0
# dew          0
# temp         0
# press        0
# wnd_dir      0
# wnd_spd      0
# snow         0
# rain         0
# dtype: int64
# ----------------
#  dew          0
# temp         0
# press        0
# wnd_dir      0
# wnd_spd      0
# snow         0
# rain         0
# pollution    0
# dtype: int64

# %%
df_train.describe()
# Out:
#           pollution           dew          temp         press       wnd_spd  \
# count  43800.000000  43800.000000  43800.000000  43800.000000  43800.000000
# mean      94.013516      1.828516     12.459041   1016.447306     23.894307
# std       92.252276     14.429326     12.193384     10.271411     50.022729
# min        0.000000    -40.000000    -19.000000    991.000000      0.450000
# 25%       24.000000    -10.000000      2.000000   1008.000000      1.790000
# 50%       68.000000      2.000000     14.000000   1016.000000      5.370000
# 75%      132.250000     15.000000     23.000000   1025.000000     21.910000
# max      994.000000     28.000000     42.000000   1046.000000    585.600000
#
#                snow          rain
# count  43800.000000  43800.000000
# mean       0.052763      0.195023
# std        0.760582      1.416247
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max       27.000000     36.000000

# %%
df_train_scaled = df_train.copy()
df_test_scaled = df_test.copy()

# Define the mapping dictionary
mapping = {'NE': 0, 'SE': 1, 'NW': 2, 'cv': 3}

# Replace the string values with numerical values
df_train_scaled['wnd_dir'] = df_train_scaled['wnd_dir'].map(mapping)
df_test_scaled['wnd_dir'] = df_test_scaled['wnd_dir'].map(mapping)

df_train_scaled['date'] = pd.to_datetime(df_train_scaled['date'])
# Resetting the index
df_train_scaled.set_index('date', inplace=True)
df_train_scaled.head()
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd  snow  \
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        1     1.79     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        1     2.68     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        1     3.57     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        1     5.36     1
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        1     6.25     2
#
#                      rain
# date
# 2010-01-02 00:00:00     0
# 2010-01-02 01:00:00     0
# 2010-01-02 02:00:00     0
# 2010-01-02 03:00:00     0
# 2010-01-02 04:00:00     0

# %%
values = df_train_scaled.values

# specify columns to plot
groups = [1, 2, 3, 5, 6]
i = 1

# plot each column
plt.figure(figsize=(20,14))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group], color=cm.plasma(group/len(groups)))
    plt.xlabel('Index')
    plt.title(df_train.columns[group], y=0.75, loc='right', fontsize = 15)
    i += 1
plt.show()

# %%
sns.set(style="darkgrid")

fig, axs = plt.subplots(3,2, figsize=(24,14))

sns.histplot(data=df_test_scaled, x="pollution", kde=True, color="skyblue", ax=axs[0, 0])
sns.histplot(data=df_test_scaled, x="dew", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df_test_scaled, x="temp", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df_test_scaled, x="press", kde=True, color="teal", ax=axs[1, 1])
sns.histplot(data=df_test_scaled, x="wnd_dir", kde=True, color="steelblue", ax=axs[2, 0])
sns.histplot(data=df_test_scaled, x="wnd_spd", kde=True, color="goldenrod", ax=axs[2, 1])

plt.show()

# %%
scaler = MinMaxScaler()

# Define the columns to scale
columns = (['pollution', 'dew', 'temp', 'press', "wnd_dir", 'wnd_spd',
       'snow', 'rain'])
    
df_test_scaled = df_test_scaled[columns]

# Scale the selected columns to the range 0-1
df_train_scaled[columns] = scaler.fit_transform(df_train_scaled[columns])
df_test_scaled[columns] = scaler.transform(df_test_scaled[columns])

# Show the scaled data
df_train_scaled.head()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.129779  0.352941  0.245902  0.527273  0.333333
# 2010-01-02 01:00:00   0.148893  0.367647  0.245902  0.527273  0.333333
# 2010-01-02 02:00:00   0.159960  0.426471  0.229508  0.545455  0.333333
# 2010-01-02 03:00:00   0.182093  0.485294  0.229508  0.563636  0.333333
# 2010-01-02 04:00:00   0.138833  0.485294  0.229508  0.563636  0.333333
#
#                       wnd_spd      snow  rain
# date
# 2010-01-02 00:00:00  0.002290  0.000000   0.0
# 2010-01-02 01:00:00  0.003811  0.000000   0.0
# 2010-01-02 02:00:00  0.005332  0.000000   0.0
# 2010-01-02 03:00:00  0.008391  0.037037   0.0
# 2010-01-02 04:00:00  0.009912  0.074074   0.0

# %%
df_test_scaled.head()
# Out:
#    pollution       dew      temp     press   wnd_dir   wnd_spd  snow  rain
# 0   0.128773  0.352941  0.377049  0.654545  0.333333  0.005349   0.0   0.0
# 1   0.077465  0.338235  0.393443  0.654545  0.333333  0.012219   0.0   0.0
# 2   0.065392  0.352941  0.377049  0.654545  0.333333  0.015278   0.0   0.0
# 3   0.079477  0.352941  0.327869  0.672727  1.000000  0.000752   0.0   0.0
# 4   0.093561  0.382353  0.311475  0.672727  0.000000  0.002290   0.0   0.0

# %%
df_train_scaled = np.array(df_train_scaled)
df_test_scaled = np.array(df_test_scaled)

X = []
y = []
n_future = 1
n_past = 11

#  Train Sets
for i in range(n_past, len(df_train_scaled) - n_future+1):
    X.append(df_train_scaled[i - n_past:i, 1:df_train_scaled.shape[1]])
    y.append(df_train_scaled[i + n_future - 1:i + n_future, 0])
X_train, y_train = np.array(X), np.array(y)

#  Test Sets

X = []
y = []
for i in range(n_past, len(df_test_scaled) - n_future+1):
    X.append(df_test_scaled[i - n_past:i, 1:df_test_scaled.shape[1]])
    y.append(df_test_scaled[i + n_future - 1:i + n_future, 0])
X_test, y_test = np.array(X), np.array(y)

print('X_train shape : {}   y_train shape : {} \n'
      'X_test shape : {}      y_test shape : {} '.format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X_train shape : (43789, 11, 7)   y_train shape : (43789, 1)
# X_test shape : (335, 11, 7)      y_test shape : (335, 1)

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(16, return_sequences=False))
model.add(Dense(y_train.shape[1]))

# Compile the model
model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

# Define callbacks for avoiding overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 11, 32)            5120
#
#  dropout (Dropout)           (None, 11, 32)            0
#
#  lstm_1 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 8,273
# Trainable params: 8,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, checkpoint], shuffle=False)
# Out:
# Epoch 1/150
# 1232/1232 [==============================] - 84s 38ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 2/150
# 1232/1232 [==============================] - 34s 27ms/step - loss: 0.0068 - root_mean_squared_error: 0.0826 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 3/150
# 1232/1232 [==============================] - 33s 27ms/step - loss: 0.0065 - root_mean_squared_error: 0.0806 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 4/150
# 1232/1232 [==============================] - 33s 27ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 5/150
# 1232/1232 [==============================] - 33s 27ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 6/150
# 1232/1232 [==============================] - 34s 27ms/step - loss: 0.0061 - root_mean_squared_error: 0.0779 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 7/150
# 1232/1232 [==============================] - 32s 26ms/step - loss: 0.0059 - root_mean_squared_error: 0.0770 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 8/150
# 1232/1232 [==============================] - 35s 28ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 9/150
# 1232/1232 [==============================] - 33s 27ms/step - loss: 0.0057 - root_mean_squared_error: 0.0758 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 10/150
# 1232/1232 [==============================] - 34s 27ms/step - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 11/150
# 1232/1232 [==============================] - 33s 27ms/step - loss: 0.0057 - root_mean_squared_error: 0.0753 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0893
# Epoch 12/150
# 1232/1232 [==============================] - 35s 28ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 13/150
# 1232/1232 [==============================] - 16741s 14s/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0828
# Epoch 14/150
# 1232/1232 [==============================] - 23996s 19s/step - loss: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 15/150
# 1232/1232 [==============================] - 18s 15ms/step - loss: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 16/150
# 1232/1232 [==============================] - 19s 15ms/step - loss: 0.0055 - root_mean_squared_error: 0.0742 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 17/150
# 1232/1232 [==============================] - 18s 15ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0765
# Epoch 18/150
# 1232/1232 [==============================] - 18s 14ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 19/150
# 1232/1232 [==============================] - 28s 22ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0753
# Epoch 20/150
# 1232/1232 [==============================] - 40s 32ms/step - loss: 0.0054 - root_mean_squared_error: 0.0738 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0743
# Epoch 21/150
# 1232/1232 [==============================] - 38s 31ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0738
# Epoch 22/150
# 1232/1232 [==============================] - 37s 30ms/step - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0734
# Epoch 23/150
# 1232/1232 [==============================] - 38s 31ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0730
# Epoch 24/150
# 1232/1232 [==============================] - 36s 30ms/step - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0726
# Epoch 25/150
# 1232/1232 [==============================] - 46s 37ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 26/150
# 1232/1232 [==============================] - 24s 20ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 27/150
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 28/150
# 1232/1232 [==============================] - 13s 11ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0711
# Epoch 29/150
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 30/150
# 1232/1232 [==============================] - 12s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 31/150
# 1232/1232 [==============================] - 13s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0731 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 32/150
# 1232/1232 [==============================] - 12s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0731 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 33/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 34/150
# 1232/1232 [==============================] - 12s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 35/150
# 1232/1232 [==============================] - 12s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 36/150
# 1232/1232 [==============================] - 12s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 37/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 38/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 39/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 40/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 41/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 42/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 43/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 44/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 45/150
# 1232/1232 [==============================] - 12s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 46/150
# 1232/1232 [==============================] - 12s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 47/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0692
# Epoch 48/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 49/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 50/150
# 1232/1232 [==============================] - 12s 9ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 51/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0716 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 52/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 53/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 54/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 55/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 56/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 57/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 58/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 59/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0692
# Epoch 60/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 61/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 62/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 63/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 64/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 65/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 66/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 67/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 68/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 69/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 70/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 71/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0700 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 72/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676
# Epoch 73/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 74/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 75/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 76/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 77/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 78/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 79/150
# 1232/1232 [==============================] - 10s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 80/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 81/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 82/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 83/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 84/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 85/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 86/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 87/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0689 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 88/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0689 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 89/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 90/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0652
# Epoch 91/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0652
# Epoch 92/150
# 1232/1232 [==============================] - 9s 7ms/step - loss: 0.0046 - root_mean_squared_error: 0.0682 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 93/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0046 - root_mean_squared_error: 0.0682 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0651
# Epoch 94/150
# 1232/1232 [==============================] - 12s 9ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 95/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 96/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 97/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0652
# Epoch 98/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 99/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0046 - root_mean_squared_error: 0.0676 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 100/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 101/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 102/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 103/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0671 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 104/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642
# Epoch 105/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642
# Epoch 106/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 107/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 108/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0667 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0637
# Epoch 109/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642
# Epoch 110/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 111/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 112/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0640
# Epoch 113/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0635
# Epoch 114/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 115/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 116/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0043 - root_mean_squared_error: 0.0654 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0640
# Epoch 117/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0635
# Epoch 118/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 119/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0643
# Epoch 120/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 121/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 122/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0042 - root_mean_squared_error: 0.0647 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0640
# Epoch 123/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 124/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642
# Epoch 125/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0041 - root_mean_squared_error: 0.0642 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 126/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 127/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0041 - root_mean_squared_error: 0.0641 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 128/150
# 1232/1232 [==============================] - 10s 8ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 129/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 130/150
# 1232/1232 [==============================] - 11s 9ms/step - loss: 0.0041 - root_mean_squared_error: 0.0637 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645

# %%
best_model = load_model('best_model.h5')

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
test_predictions = best_model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})
test_results.head()
# Out:
# 11/11 [==============================] - 1s 2ms/step
#    Train Predictions    Actual
# 0           0.120029  0.171026
# 1           0.097438  0.160966
# 2           0.101581  0.146881
# 3           0.128237  0.125755
# 4           0.110661  0.130785

# %%
plt.plot(test_results['Train Predictions'][:200], label='Predicted Values')
plt.plot(test_results['Actual'][:200], label='True Values')
plt.legend()
plt.show()

# %%
rmse = sqrt(mse(y_test, test_predictions))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.06090
